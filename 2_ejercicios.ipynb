# %% [markdown]
# # Analizando una Imagen

# %%
import matplotlib.pyplot as plt 
img = plt.imread('beagle.jpg')
img.shape

img[10,150]
# Out:
# array([113, 124,  58], dtype=uint8)

# %%
plt.imshow(img)
plt.axis("off")
plt.show()
